# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Running cells with 'c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/LENOVO/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
crop_df = pd.read_csv('/inputs/data/test.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7416246ac4cd> in <cell line: 1>()
# ----> 1 crop_df = pd.read_excel('/content/Crop_combined 2018-19.xlsx')
#
# NameError: name 'pd' is not defined

# %%
crop_df
# Out:
#         Year  Crop name District name  Min temperature  Average temperature  \
# 0    2018-19       Rice       Kachchh               25                   40
# 1    2018-19       Rice   Banaskantha               26                   34
# 2    2018-19       Rice         Patan               27                   36
# 3    2018-19       Rice       Mehsana               29                   32
# 4    2018-19       Rice   Sabarkantha               25                   33
# ..       ...        ...           ...              ...                  ...
# 325  2018-19  Sugarcane         Surat               27                   29
# 326  2018-19  Sugarcane         Dangs               25                   35
# 327  2018-19  Sugarcane       Navsari               27                   33
# 328  2018-19  Sugarcane        Valsad               28                   30
# 329  2018-19  Sugarcane          Tapi               29                   34
#
# ...

# %%
crop_df['Crop name'].value_counts()
# Out:
# Rice         33
# Wheat        33
# Jowar        33
# Bajra        33
# Cotton       33
# Maize        33
# Groundnut    33
# Soyabean     33
# Tobacco      33
# Sugarcane    33
# Name: Crop name, dtype: int64

# %%
crop_df['Crop name'].unique()
# Out:
# array(['Rice', 'Wheat', 'Jowar', 'Bajra', 'Cotton', 'Maize', 'Groundnut',
#        'Soyabean', 'Tobacco', 'Sugarcane'], dtype=object)

# %%
crop_df['District name'].unique()
# Out:
# array(['Kachchh', 'Banaskantha', 'Patan', 'Mehsana', 'Sabarkantha',
#        'Arvalli', 'Gandhinagar', 'Ahmedabad', 'Surendranagar', 'Morbi',
#        'Rajkot', 'Jamnagar', 'Devbhoomi Dwarka', 'Porbandar', 'Junagadh',
#        'Gir Somnath', 'Amreli', 'Bhavnagar', 'Botad', 'Anand', 'Kheda',
#        'Panchmahal', 'Mahisagar', 'Dahod', 'Vadodara', 'Chhhota Udepur',
#        'Narmada', 'Bharuch', 'Surat', 'Dangs', 'Navsari', 'Valsad',
#        'Tapi', 'Chhota Udepur'], dtype=object)

# %%
crop_df['District name'].value_counts()
# Out:
# Kachchh             10
# Banaskantha         10
# Tapi                10
# Valsad              10
# Navsari             10
# Dangs               10
# Surat               10
# Bharuch             10
# Narmada             10
# Vadodara            10
# Dahod               10
# Mahisagar           10
# Panchmahal          10
# Kheda               10
# Anand               10
# Botad               10
# Bhavnagar           10
# Amreli              10
# Patan               10
# Junagadh            10
# Porbandar           10
# Devbhoomi Dwarka    10
# Jamnagar            10
# Rajkot              10
# Morbi               10
# Gir Somnath         10
# Surendranagar       10
# Ahmedabad           10
# Gandhinagar         10
# Arvalli             10
# Sabarkantha         10
# Mehsana             10
# Chhota Udepur        9
# Chhhota Udepur       1
# Name: District name, dtype: int64

# %%
crop_df['District name'].replace('Chhota Udepur', 'Chhhota Udepur', inplace=True)

# %%
crop_df['District name'].value_counts()
# Out:
# Kachchh             10
# Bhavnagar           10
# Valsad              10
# Navsari             10
# Dangs               10
# Surat               10
# Bharuch             10
# Narmada             10
# Chhhota Udepur      10
# Vadodara            10
# Dahod               10
# Mahisagar           10
# Panchmahal          10
# Kheda               10
# Anand               10
# Botad               10
# Amreli              10
# Banaskantha         10
# Gir Somnath         10
# Junagadh            10
# Porbandar           10
# Devbhoomi Dwarka    10
# Jamnagar            10
# Rajkot              10
# Morbi               10
# Surendranagar       10
# Ahmedabad           10
# Gandhinagar         10
# Arvalli             10
# Sabarkantha         10
# Mehsana             10
# Patan               10
# Tapi                10
# Name: District name, dtype: int64

# %%
# 33 distirct
# 10 crops

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation=75)
sns.barplot(x=crop_df['District name'], y=crop_df['Yield']);
# plt.plot()

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation=75)
plt.title("District wise sum of all crops' yields")
plt.bar(x=crop_df['District name'], height=crop_df['Yield']);
# plt.plot()

# %%
def all_district_graph(clms,r,c,df):
    plt.figure(figsize=(30,130))
    i=1
    for clm in clms:
        df1 = df[df['District name']==clm]
        plt.subplot(r,c,i)
        plt.xticks(rotation=75)
        sns.barplot(x=df1['Crop name'], y=df1['Yield'])
        plt.title(clm)
        i+=1

# %%
districts = crop_df['District name'].unique()

# %%
all_district_graph(districts, 11, 3, crop_df)

# %%
def all_crops_graph(clms,r,c,df):
    plt.figure(figsize=(30,120))
    i=1
    for clm in clms:
        df1 = df[df['Crop name']==clm]
        plt.subplot(r,c,i)
        plt.xticks(rotation=90)
        sns.barplot(x=df1['District name'], y=df1['Yield'])
        plt.title(clm)
        i+=1

# %%
crops = crop_df['Crop name'].unique().tolist()

# %%
all_crops_graph(crops, 11, 3 , crop_df)

# %%
crop_df[crop_df['District name']=='Surat']
# Out:
#         Year  Crop name District name  Min temperature  Average temperature  \
# 28   2018-19       Rice         Surat               27                   31
# 61   2018-19      Wheat         Surat               28                   32
# 94   2018-19      Jowar         Surat               27                   32
# 127  2018-19      Bajra         Surat               27                   30
# 160  2018-19     Cotton         Surat               27                   31
# 193  2018-19      Maize         Surat               27                   30
# 226  2018-19  Groundnut         Surat               27                   33
# 259  2018-19   Soyabean         Surat               27                   30
# 292  2018-19    Tobacco         Surat               27                   30
# 325  2018-19  Sugarcane         Surat               27                   29
#
#      Max Temperature    Rain  Humidity(%)  Pressure(mb)  Wind(km/hr)    Area  \
# ...

# %%
from sklearn.linear_model import LinearRegression,  SGDRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, max_error
from sklearn.model_selection import train_test_split, cross_val_predict, cross_validate
from sklearn.preprocessing import LabelEncoder, StandardScaler
from scipy.stats import linregress

# %%
crop_df1 = crop_df.copy()

# %%
le = LabelEncoder()

obj_cols = ['Crop name', 'District name']

for i in obj_cols:
    crop_df1[i+'_new'] = le.fit_transform(crop_df1[i])

# %%
crop_df1
# Out:
#         Year  Crop name District name  Min temperature  Average temperature  \
# 0    2018-19       Rice       Kachchh               25                   40
# 1    2018-19       Rice   Banaskantha               26                   34
# 2    2018-19       Rice         Patan               27                   36
# 3    2018-19       Rice       Mehsana               29                   32
# 4    2018-19       Rice   Sabarkantha               25                   33
# ..       ...        ...           ...              ...                  ...
# 325  2018-19  Sugarcane         Surat               27                   29
# 326  2018-19  Sugarcane         Dangs               25                   35
# 327  2018-19  Sugarcane       Navsari               27                   33
# 328  2018-19  Sugarcane        Valsad               28                   30
# 329  2018-19  Sugarcane          Tapi               29                   34
#
# ...

# %%
num_clms = crop_df.select_dtypes(include = ['int','float']).columns.tolist()

# %%
num_clms
# Out:
# ['Min temperature',
#  'Average temperature',
#  'Max Temperature',
#  'Rain',
#  'Humidity(%)',
#  'Pressure(mb)',
#  'Wind(km/hr)',
#  'Area',
#  'Production',
#  'Yield']

# %%
num_clms.remove('Yield')
num_clms
# Out:
# ['Min temperature',
#  'Average temperature',
#  'Max Temperature',
#  'Rain',
#  'Humidity(%)',
#  'Pressure(mb)',
#  'Wind(km/hr)',
#  'Area',
#  'Production']

# %%
stdsclr = StandardScaler()

# %%
crop_df1[num_clms] = stdsclr.fit_transform(crop_df1[num_clms])

# %%
crop_df1
# Out:
#         Year  Crop name District name  Min temperature  Average temperature  \
# 0    2018-19       Rice       Kachchh        -1.474131             2.614843
# 1    2018-19       Rice   Banaskantha        -0.740400             0.221228
# 2    2018-19       Rice         Patan        -0.006670             1.019100
# 3    2018-19       Rice       Mehsana         1.460790            -0.576644
# 4    2018-19       Rice   Sabarkantha        -1.474131            -0.177708
# ..       ...        ...           ...              ...                  ...
# 325  2018-19  Sugarcane         Surat        -0.006670            -1.773451
# 326  2018-19  Sugarcane         Dangs        -1.474131             0.620164
# 327  2018-19  Sugarcane       Navsari        -0.006670            -0.177708
# 328  2018-19  Sugarcane        Valsad         0.727060            -1.374515
# 329  2018-19  Sugarcane          Tapi         1.460790             0.221228
#
# ...

# %%
linreg = LinearRegression(n_jobs=-1)
rfreg = RandomForestRegressor(n_estimators=5000, max_depth=10, n_jobs=-1)
dtreg = DecisionTreeRegressor(max_depth=9)
knnreg = KNeighborsRegressor(n_neighbors=10, n_jobs=-1)
sgdreg = SGDRegressor(alpha = 0.01)
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
gnb = GaussianNB()

# %%
x_train, x_test, y_train, y_test = train_test_split(crop_df.drop(['Yield','Crop name', 'District name', 'Year'], axis=1), crop_df['Yield'], test_size=0.2, random_state=42)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((264, 9), (264,), (66, 9), (66,))

# %%
type(x_train)
# Out:
# pandas.core.frame.DataFrame

# %%
estimators = [('Linear Regression', linreg),
              ('Stochastic gradient desecent regression', sgdreg),
              ('Decision tree regression', dtreg),
              ('Random forest regression', rfreg),
              ('K-nearest neighbour 5', knnreg)]

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def plot_regression_results(ax, y_test, y_pred, title, estimated_time, scores):

  # linear least-squares
  slope, intercept, rvalue, pvalue, stderr = linregress(y_test, y_pred)
  ax.plot([y_test.min(), y_test.max()], [intercept+y_test.min()*slope, intercept+y_test.max()*slope], '--r')

  ax.scatter(y_test, y_pred, alpha=0.7)

  # Anzeigen der Werte in einer Box
  extra = plt.Rectangle((0, 0), 0, 0, fc="w", fill=False,
                          edgecolor='none', linewidth=0)
  ax.legend([extra], [scores], loc='upper left')

  ax.set_xlabel('Actual values in tonnes')
  ax.set_ylabel('Predictes values in tonnes')
  ax.set_title('{}\nTrained in {:.2f} Milliseconds'.format(name, estimated_time*1000))

# %%
import time
fig, axs = plt.subplots(nrows=2,ncols=3,sharex = True, sharey=True, figsize=(20,13))
axs = np.ravel(axs)

for ax, (name, est) in zip(axs, estimators):
  start_time = time.time()
  # Trainieren des Modelles
  est.fit(x_train, y_train)
  y_pred = est.predict(x_test)
  estimated_time = time.time() - start_time

  # Anzeigen des Modelles
  plot_regression_results(ax, y_test, y_pred, name, estimated_time,
                          (r'$R^2$ = {:.2f}' + '\n' +
                          r'MAE = {:.0f}' + '\n' +
                          r'MSE = {:.0f}' + '\n' +
                          r'RMSE = {:.0f}' + '\n' +
                          r'MAX = {:.0f}' + '\n' +
                          r'MAPE = {:.2f}%')
                          .format(r2_score(y_test, y_pred),
                                  mean_absolute_error(y_test, y_pred),
                                  mean_squared_error(y_test, y_pred),
                                  mean_squared_error(y_test, y_pred, squared=False),
                                  max_error(y_test, y_pred),
                                  mean_absolute_percentage_error(y_test, y_pred)))

plt.suptitle('Regressionsverfahren')
plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.show()
# Out:
# <ipython-input-40-199972fad748>:3: RuntimeWarning: divide by zero encountered in true_divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# <ipython-input-40-199972fad748>:3: RuntimeWarning: divide by zero encountered in true_divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# <ipython-input-40-199972fad748>:3: RuntimeWarning: invalid value encountered in true_divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# <ipython-input-40-199972fad748>:3: RuntimeWarning: divide by zero encountered in true_divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# <ipython-input-40-199972fad748>:3: RuntimeWarning: invalid value encountered in true_divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# <ipython-input-40-199972fad748>:3: RuntimeWarning: divide by zero encountered in true_divide
#   return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
